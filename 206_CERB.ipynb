# %%
print("Operadores Matematicos")
print("Realiza la suma 4 + 4=", 4 + 4)
print("Realiza la resta 8 - 6 =" , 8 - 6)
# Out:
# Operadores Matematicos
# Realiza la suma 4 + 4= 8
# Realiza la resta 8 - 6 = 2

# %%
print("Realiza la suma 2 + 2=" ,2 + 2)
# Out:
# Realiza la suma 2 + 2= 4

# %%
print("Realiza la suma 10 + 10=", 10 + 10)
# Out:
# Realiza la suma 10 + 10= 20

# %%
print("Realiza la suma 15 + 15=", 15 +15)
# Out:
# Realiza la suma 15 + 15= 30

# %%
print("Realiza la suma 20 + 20=", 20 + 20)
# Out:
# Realiza la suma 20 + 20= 40

# %%
print("Realiza la suma 18 + 18=" , 18 + 18)
# Out:
# Realiza la suma 18 + 18= 36

# %%
print("Realiza la suma 12 + 12=", 12 + 12)
# Out:
# Realiza la suma 12 + 12= 24

# %%
print("Reañiza la suma 34 + 34=", 34 + 33 )
# Out:
# Reañiza la suma 34 + 34= 67

# %%
print("Realiza la suma 13 + 51=", 13 + 51)
# Out:
# Realiza la suma 13 + 51= 64

# %%
print("Realiza la suma 43 + 23=", 43 + 23)
# Out:
# Realiza la suma 43 + 23= 66

# %%
print("Realiza la suma 12 + 32=", 12 + 32)
# Out:
# Realiza la suma 12 + 32= 44

# %%
print("Realiza la resta 5 - 6=", 5 - 6)
# Out:
# Realiza la resta 5 - 6= -1

# %%
print("Realiza la resta 56 - 34 =", 56 - 34)
# Out:
# Realiza la resta 56 - 34 = 22

# %%
print("Realiza la resta 12 - 10= ", 12 - 10)
# Out:
# Realiza la resta 12 - 10=  2

# %%
print("Realiza la resta 34 - 45", 34 - 45)
# Out:
# Realiza la resta 34 - 45 -11

# %%
print("Realiza la resta  78 - 54 =" , 78 - 54)
# Out:
# Realiza la resta  78 - 54 = 24

# %%
print("Realiza la resta  59 - 30 =" , 59 - 30)
# Out:
# Realiza la resta  59 - 30 = 29

# %%
print("Realiza la resta  100 - 76 =", 100 - 23)
# Out:
# Realiza la resta  100 - 76 = 77

# %%
print("Realiza la resta 76 - 23 =", 76 - 23)
# Out:
# Realiza la resta 76 - 23 = 53

# %%
print("Realiza la resta  99 - 98 =" , 99 - 98)
# Out:
# Realiza la resta  99 - 98 = 1

# %%
print("Realiza la resta 59 - 2 =", 59 - 2)
# Out:
# Realiza la resta 59 - 2 = 57

# %%
print("Realiza la multiplicacion 7 * 8 =", 7 * 8)
# Out:
# Realiza la multiplicacion 7 * 8 = 56

# %%
print("Realiza la multiplicacion 9 * 9 =", 9 * 9)
# Out:
# Realiza la multiplicacion 9 * 9 = 81

# %%
print("Realiza la multiplicacion 12 * 4 =", 12 * 4)
# Out:
# Realiza la multiplicacion 12 * 4 = 48

# %%
print("Realiza la multiplicacion 5 * 6 =", 5 * 6)
# Out:
# Realiza la multiplicacion 5 * 6 = 30

# %%
print("Realiza la multiplicacion 8 * 8 =", 8 * 8 )
# Out:
# Realiza la multiplicacion 8 * 8 = 64

# %%
print("Realiza la multiplicacion  2 * 2 =", 2 * 2)
# Out:
# Realiza la multiplicacion  2 * 2 = 4

# %%
print("Realiza la multiplicacion 4 * 4 =", 4 * 4)
# Out:
# Realiza la multiplicacion 4 * 4 = 16

# %%
print("Realiza la multiplicacion 6 * 9 =", 6 * 9)
# Out:
# Realiza la multiplicacion 6 * 9 = 54

# %%
print("Realiza la multiplicacion 9 * 5 =", 9 * 5)
# Out:
# Realiza la multiplicacion 9 * 5 = 45

# %%
print("Realiza la multiplicacion 11 * 11 =", 11 * 11)
# Out:
# Realiza la multiplicacion 11 * 11 = 121

# %%
print("Realiza la division 56 / 5 =", 56 / 5)
# Out:
# Realiza la division 56 / 5 = 11.2

# %%
print("Realiza la division 134 / 7 =", 134 / 7)
# Out:
# Realiza la division 134 / 7 = 19.142857142857142

# %%
print("Realiza la division 45 / 5 =" , 45 / 5)
# Out:
# Realiza la division 45 / 5 = 9.0

# %%
print("Realiza  la division 78 / 9 =" ,78 / 9)
# Out:
# Realiza  la division 78 / 9 = 8.666666666666666

# %%
print("Realiza la division  120 / 6 =", 120 / 6)
# Out:
# Realiza la division  120 / 6 = 20.0

# %%
print("Realiza la division  20 / 4 =" , 20 / 4)
# Out:
# Realiza la division  20 / 4 = 5.0

# %%
print("Realiza la division  60 / 2 =" , 60 / 2)
# Out:
# Realiza la division  60 / 2 = 30.0

# %%
print("Realiza la division 100 / 50 =", 100 / 50)
# Out:
# Realiza la division 100 / 50 = 2.0

# %%
print("Realiza la division  67 / 6 =", 67 / 6)
# Out:
# Realiza la division  67 / 6 = 11.166666666666666

# %%
print("Realiza la division  99 / 6 =", 99 / 6)
# Out:
# Realiza la division  99 / 6 = 16.5
